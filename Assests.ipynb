# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
trad = pd.read_csv("equity_fixedincome.csv", index_col = "Date", parse_dates = ["Date"])
trad
# Out:
#             USEquity  Europe  EmergMarkets  GovBonds  CorpBonds
# Date
# 2018-01-02    224.65  116.23         43.05    180.38      96.37
# 2018-01-03    226.09  117.00         43.47    180.80      96.63
# 2018-01-04    227.00  118.96         43.68    180.11      96.32
# 2018-01-05    228.60  120.25         44.06    180.30      96.54
# 2018-01-08    228.98  120.55         44.06    181.04      97.01
# ...              ...     ...           ...       ...        ...
# 2022-12-23    320.40  127.23         37.80    173.26      95.83
# 2022-12-27    319.10  127.76         38.36    171.70      94.77
# 2022-12-28    315.27  126.96         37.80    171.52      94.26
# 2022-12-29    320.77  128.34         38.43    171.47      94.16
# 2022-12-30    319.96  126.45         37.90    171.38      93.98
#
# [1259 rows x 5 columns]

# %%
trad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2018-01-02 to 2022-12-30
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   USEquity      1259 non-null   float64
#  1   Europe        1227 non-null   float64
#  2   EmergMarkets  1259 non-null   float64
#  3   GovBonds      1237 non-null   float64
#  4   CorpBonds     1237 non-null   float64
# dtypes: float64(5)
# memory usage: 59.0 KB

# %%
trad.plot(figsize = (12, 8))
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize= (15, 12))
sns.heatmap(trad.isna(), yticklabels= False)
plt.show()

# %%
trad.fillna(method = "ffill", inplace = True)
trad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2018-01-02 to 2022-12-30
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   USEquity      1259 non-null   float64
#  1   Europe        1259 non-null   float64
#  2   EmergMarkets  1259 non-null   float64
#  3   GovBonds      1259 non-null   float64
#  4   CorpBonds     1259 non-null   float64
# dtypes: float64(5)
# memory usage: 59.0 KB

# %%
crypto = pd.read_csv("crypto.csv", index_col = "Time", parse_dates = ["Time"])
crypto
# Out:
#                        Open    High     Low   Close
# Time
# 2018-01-01 01:00:00  114.30  114.30  111.67  112.74
# 2018-01-01 02:00:00  112.74  113.30  109.63  110.03
# 2018-01-01 03:00:00  110.02  111.82  110.00  111.08
# 2018-01-01 04:00:00  111.09  113.43  110.75  111.75
# 2018-01-01 05:00:00  111.96  113.53  111.02  113.34
# ...                     ...     ...     ...     ...
# 2023-01-31 21:00:00  193.02  193.11  192.04  192.46
# 2023-01-31 22:00:00  192.46  192.70  190.11  191.24
# 2023-01-31 23:00:00  191.23  194.33  190.60  193.18
# 2023-02-01 00:00:00  193.18  193.24  192.34  192.71
# 2023-02-01 01:00:00  192.71  193.07  191.64  192.38
#
# [44448 rows x 4 columns]

# %%
crypto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 44448 entries, 2018-01-01 01:00:00 to 2023-02-01 01:00:00
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    44448 non-null  float64
#  1   High    44448 non-null  float64
#  2   Low     44448 non-null  float64
#  3   Close   44448 non-null  float64
# dtypes: float64(4)
# memory usage: 1.7 MB

# %%
crypto.plot(figsize = (12, 8))
plt.show()

# %%
crypto = crypto["Close"].to_frame()

# %%
crypto.columns = ["Crypto"]
crypto
# Out:
#                      Crypto
# Time
# 2018-01-01 01:00:00  112.74
# 2018-01-01 02:00:00  110.03
# 2018-01-01 03:00:00  111.08
# 2018-01-01 04:00:00  111.75
# 2018-01-01 05:00:00  113.34
# ...                     ...
# 2023-01-31 21:00:00  192.46
# 2023-01-31 22:00:00  191.24
# 2023-01-31 23:00:00  193.18
# 2023-02-01 00:00:00  192.71
# 2023-02-01 01:00:00  192.38
#
# [44448 rows x 1 columns]

# %%
print(crypto.index.tzinfo)
# Out:
# None

# %%
crypto = crypto.tz_localize(tz = "Europe/Berlin", ambiguous = "infer")
crypto
# Out:
#                            Crypto
# Time
# 2018-01-01 01:00:00+01:00  112.74
# 2018-01-01 02:00:00+01:00  110.03
# 2018-01-01 03:00:00+01:00  111.08
# 2018-01-01 04:00:00+01:00  111.75
# 2018-01-01 05:00:00+01:00  113.34
# ...                           ...
# 2023-01-31 21:00:00+01:00  192.46
# 2023-01-31 22:00:00+01:00  191.24
# 2023-01-31 23:00:00+01:00  193.18
# 2023-02-01 00:00:00+01:00  192.71
# 2023-02-01 01:00:00+01:00  192.38
#
# [44448 rows x 1 columns]

# %%
crypto = crypto.tz_convert(tz = "US/Eastern")
crypto
# Out:
#                            Crypto
# Time
# 2017-12-31 19:00:00-05:00  112.74
# 2017-12-31 20:00:00-05:00  110.03
# 2017-12-31 21:00:00-05:00  111.08
# 2017-12-31 22:00:00-05:00  111.75
# 2017-12-31 23:00:00-05:00  113.34
# ...                           ...
# 2023-01-31 15:00:00-05:00  192.46
# 2023-01-31 16:00:00-05:00  191.24
# 2023-01-31 17:00:00-05:00  193.18
# 2023-01-31 18:00:00-05:00  192.71
# 2023-01-31 19:00:00-05:00  192.38
#
# [44448 rows x 1 columns]

# %%
crypto = crypto.tz_convert(tz = "US/Eastern")
crypto
# Out:
#                            Crypto
# Time
# 2017-12-31 19:00:00-05:00  112.74
# 2017-12-31 20:00:00-05:00  110.03
# 2017-12-31 21:00:00-05:00  111.08
# 2017-12-31 22:00:00-05:00  111.75
# 2017-12-31 23:00:00-05:00  113.34
# ...                           ...
# 2023-01-31 15:00:00-05:00  192.46
# 2023-01-31 16:00:00-05:00  191.24
# 2023-01-31 17:00:00-05:00  193.18
# 2023-01-31 18:00:00-05:00  192.71
# 2023-01-31 19:00:00-05:00  192.38
#
# [44448 rows x 1 columns]

# %%
crypto.index.tzinfo
# Out:
# <DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>

# %%
crypto = crypto.resample(rule = "d").last()
crypto
# Out:
#                            Crypto
# Time
# 2017-12-31 00:00:00-05:00  113.34
# 2018-01-01 00:00:00-05:00  109.39
# 2018-01-02 00:00:00-05:00  125.16
# 2018-01-03 00:00:00-05:00  126.00
# 2018-01-04 00:00:00-05:00  123.50
# ...                           ...
# 2023-01-27 00:00:00-05:00  192.44
# 2023-01-28 00:00:00-05:00  193.57
# 2023-01-29 00:00:00-05:00  197.65
# 2023-01-30 00:00:00-05:00  190.51
# 2023-01-31 00:00:00-05:00  192.38
#
# [1858 rows x 1 columns]

# %%
crypto.index = crypto.index.date

# %%
crypto.index.name = "Date"
crypto
# Out:
#             Crypto
# Date
# 2017-12-31  113.34
# 2018-01-01  109.39
# 2018-01-02  125.16
# 2018-01-03  126.00
# 2018-01-04  123.50
# ...            ...
# 2023-01-27  192.44
# 2023-01-28  193.57
# 2023-01-29  197.65
# 2023-01-30  190.51
# 2023-01-31  192.38
#
# [1858 rows x 1 columns]

# %%
alter = pd.read_csv("alternative.csv", parse_dates = ["Date"])
alter
# Out:
#                   Date  Commodities  RealEstate
# 0     Date: 2018-01-02         8.21       21.24
# 1     Date: 2018-01-03         8.23       21.27
# 2     Date: 2018-01-04         8.25       20.97
# 3     Date: 2018-01-05         8.25       21.02
# 4     Date: 2018-01-08         8.24       21.05
# ...                ...          ...         ...
# 1255  Date: 2022-12-23        11.22       22.56
# 1256  Date: 2022-12-27        11.34       22.54
# 1257  Date: 2022-12-28        11.30       22.22
# 1258  Date: 2022-12-29        11.37       22.69
# 1259  Date: 2022-12-30        11.37       22.55
#
# [1260 rows x 3 columns]

# %%
type(alter.loc[0, "Date"])
# Out:
# str

# %%
alter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         1260 non-null   object
#  1   Commodities  1260 non-null   float64
#  2   RealEstate   1260 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 29.7+ KB

# %%
alter.plot(figsize = (12, 8))
plt.show()

# %%
alter.Date = alter.Date.str.replace(pat = "Date: ", repl =  "")
alter
# Out:
#             Date  Commodities  RealEstate
# 0     2018-01-02         8.21       21.24
# 1     2018-01-03         8.23       21.27
# 2     2018-01-04         8.25       20.97
# 3     2018-01-05         8.25       21.02
# 4     2018-01-08         8.24       21.05
# ...          ...          ...         ...
# 1255  2022-12-23        11.22       22.56
# 1256  2022-12-27        11.34       22.54
# 1257  2022-12-28        11.30       22.22
# 1258  2022-12-29        11.37       22.69
# 1259  2022-12-30        11.37       22.55
#
# [1260 rows x 3 columns]

# %%
alter.Date = pd.to_datetime(alter.Date)

# %%
alter.set_index(keys = "Date", inplace = True)
alter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1260 entries, 2018-01-02 to 2022-12-30
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Commodities  1260 non-null   float64
#  1   RealEstate   1260 non-null   float64
# dtypes: float64(2)
# memory usage: 29.5 KB

# %%
crypto = crypto.reindex(trad.index)
alter = alter.reindex(trad.index)

# %%
all_assets = pd.concat([trad, crypto, alter], axis = 1)
all_assets
# Out:
#             USEquity  Europe  EmergMarkets  GovBonds  CorpBonds  Crypto  \
# Date
# 2018-01-02    224.65  116.23         43.05    180.38      96.37  125.16
# 2018-01-03    226.09  117.00         43.47    180.80      96.63  126.00
# 2018-01-04    227.00  118.96         43.68    180.11      96.32  123.50
# 2018-01-05    228.60  120.25         44.06    180.30      96.54  137.25
# 2018-01-08    228.98  120.55         44.06    181.04      97.01  127.91
# ...              ...     ...           ...       ...        ...     ...
# 2022-12-23    320.40  127.23         37.80    173.26      95.83  140.24
# 2022-12-27    319.10  127.76         38.36    171.70      94.77  138.84
# 2022-12-28    315.27  126.96         37.80    171.52      94.26  138.10
# 2022-12-29    320.77  128.34         38.43    171.47      94.16  138.45
# 2022-12-30    319.96  126.45         37.90    171.38      93.98  137.93
#
#             Commodities  RealEstate
# Date
# 2018-01-02         8.21       21.24
# 2018-01-03         8.23       21.27
# 2018-01-04         8.25       20.97
# 2018-01-05         8.25       21.02
# 2018-01-08         8.24       21.05
# ...                 ...         ...
# 2022-12-23        11.22       22.56
# 2022-12-27        11.34       22.54
# 2022-12-28        11.30       22.22
# 2022-12-29        11.37       22.69
# 2022-12-30        11.37       22.55
#
# [1259 rows x 8 columns]

# %%
all_assets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2018-01-02 to 2022-12-30
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   USEquity      1259 non-null   float64
#  1   Europe        1259 non-null   float64
#  2   EmergMarkets  1259 non-null   float64
#  3   GovBonds      1259 non-null   float64
#  4   CorpBonds     1259 non-null   float64
#  5   Crypto        1258 non-null   float64
#  6   Commodities   1259 non-null   float64
#  7   RealEstate    1259 non-null   float64
# dtypes: float64(8)
# memory usage: 88.5 KB

# %%
all_assets[all_assets.Crypto.isna()]
# Out:
#             USEquity  Europe  EmergMarkets  GovBonds  CorpBonds  Crypto  \
# Date
# 2018-02-08    215.08  112.58         40.97     177.0      92.71     NaN
#
#             Commodities  RealEstate
# Date
# 2018-02-08         8.23        19.2

# %%
all_assets["Crypto"] = all_assets.Crypto.interpolate()

# %%
norm = all_assets.div(all_assets.iloc[0]).mul(100)
norm
# Out:
#               USEquity      Europe  EmergMarkets    GovBonds   CorpBonds  \
# Date
# 2018-01-02  100.000000  100.000000    100.000000  100.000000  100.000000
# 2018-01-03  100.640997  100.662480    100.975610  100.232842  100.269794
# 2018-01-04  101.046072  102.348791    101.463415   99.850316   99.948117
# 2018-01-05  101.758291  103.458660    102.346109   99.955649  100.176403
# 2018-01-08  101.927443  103.716768    102.346109  100.365894  100.664107
# ...                ...         ...           ...         ...         ...
# 2022-12-23  142.621856  109.463994     87.804878   96.052777   99.439660
# 2022-12-27  142.043178  109.919986     89.105691   95.187937   98.339732
# 2022-12-28  140.338304  109.231696     87.804878   95.088147   97.810522
# 2022-12-29  142.786557  110.418997     89.268293   95.060428   97.706755
# 2022-12-30  142.425996  108.792911     88.037166   95.010533   97.519975
#
#                 Crypto  Commodities  RealEstate
# Date
# 2018-01-02  100.000000   100.000000  100.000000
# 2018-01-03  100.671141   100.243605  100.141243
# 2018-01-04   98.673698   100.487211   98.728814
# 2018-01-05  109.659636   100.487211   98.964218
# 2018-01-08  102.197188   100.365408   99.105461
# ...                ...          ...         ...
# 2022-12-23  112.048578   136.662607  106.214689
# 2022-12-27  110.930010   138.124239  106.120527
# 2022-12-28  110.338766   137.637028  104.613936
# 2022-12-29  110.618408   138.489647  106.826742
# 2022-12-30  110.202940   138.489647  106.167608
#
# [1259 rows x 8 columns]

# %%
norm.plot(figsize = (12, 8))
plt.show()

# %%
norm.loc["2018":"2020-01-15", ["USEquity", "Europe", "EmergMarkets"]].plot(figsize = (12, 8))
plt.show()

# %%
returns = all_assets.pct_change().dropna()
returns
# Out:
#             USEquity    Europe  EmergMarkets  GovBonds  CorpBonds    Crypto  \
# Date
# 2018-01-03  0.006410  0.006625      0.009756  0.002328   0.002698  0.006711
# 2018-01-04  0.004025  0.016752      0.004831 -0.003816  -0.003208 -0.019841
# 2018-01-05  0.007048  0.010844      0.008700  0.001055   0.002284  0.111336
# 2018-01-08  0.001662  0.002495      0.000000  0.004104   0.004868 -0.068051
# 2018-01-09  0.001266  0.001742     -0.001589  0.001989   0.001237 -0.072238
# ...              ...       ...           ...       ...        ...       ...
# 2022-12-23  0.005871 -0.001648     -0.001321 -0.004196  -0.003224 -0.000499
# 2022-12-27 -0.004057  0.004166      0.014815 -0.009004  -0.011061 -0.009983
# 2022-12-28 -0.012003 -0.006262     -0.014599 -0.001048  -0.005381 -0.005330
# 2022-12-29  0.017445  0.010870      0.016667 -0.000292  -0.001061  0.002534
# 2022-12-30 -0.002525 -0.014727     -0.013791 -0.000525  -0.001912 -0.003756
#
#             Commodities  RealEstate
# Date
# 2018-01-03     0.002436    0.001412
# 2018-01-04     0.002430   -0.014104
# 2018-01-05     0.000000    0.002384
# 2018-01-08    -0.001212    0.001427
# 2018-01-09    -0.004854   -0.005701
# ...                 ...         ...
# 2022-12-23     0.004476    0.008945
# 2022-12-27     0.010695   -0.000887
# 2022-12-28    -0.003527   -0.014197
# 2022-12-29     0.006195    0.021152
# 2022-12-30     0.000000   -0.006170
#
# [1258 rows x 8 columns]

# %%
plt.figure(figsize= (12, 8))
sns.violinplot(data = returns)
plt.show()

# %%
import numpy as np

# %%
ann_return = returns.mean() * 252
ann_return
# Out:
# USEquity        0.094881
# Europe          0.038807
# EmergMarkets    0.001788
# GovBonds       -0.008253
# CorpBonds       0.000034
# Crypto          0.300327
# Commodities     0.076906
# RealEstate      0.037597
# dtype: float64

# %%
ann_risk = returns.std() * np.sqrt(252)
ann_risk
# Out:
# USEquity        0.218690
# Europe          0.208758
# EmergMarkets    0.232909
# GovBonds        0.063288
# CorpBonds       0.100622
# Crypto          0.742809
# Commodities     0.152774
# RealEstate      0.224237
# dtype: float64

# %%
plt.figure(figsize = (15, 12))
plt.scatter(x = ann_risk, y = ann_return)
for i in ann_risk.index:
    plt.annotate(i, xy=(ann_risk[i], ann_return[i]), size = 10)
plt.xlabel("annualized Risk")
plt.ylabel("annualized Return")
plt.show()

# %%
corr_matrix = returns.corr()
corr_matrix
# Out:
#               USEquity    Europe  EmergMarkets  GovBonds  CorpBonds    Crypto  \
# USEquity      1.000000  0.605900      0.784037 -0.133767   0.224511  0.252159
# Europe        0.605900  1.000000      0.611035 -0.231723   0.165318  0.174506
# EmergMarkets  0.784037  0.611035      1.000000 -0.208248   0.115967  0.240164
# GovBonds     -0.133767 -0.231723     -0.208248  1.000000   0.673031  0.004597
# CorpBonds     0.224511  0.165318      0.115967  0.673031   1.000000  0.072935
# Crypto        0.252159  0.174506      0.240164  0.004597   0.072935  1.000000
# Commodities   0.090180  0.043852      0.151436  0.055231   0.039007  0.116352
# RealEstate    0.776982  0.565589      0.632364 -0.052151   0.288000  0.197095
#
#               Commodities  RealEstate
# USEquity         0.090180    0.776982
# Europe           0.043852    0.565589
# EmergMarkets     0.151436    0.632364
# GovBonds         0.055231   -0.052151
# CorpBonds        0.039007    0.288000
# Crypto           0.116352    0.197095
# Commodities      1.000000    0.151105
# RealEstate       0.151105    1.000000

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix, square = True, annot = True, cmap = "RdBu")
plt.show()
